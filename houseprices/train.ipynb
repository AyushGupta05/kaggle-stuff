# %%
import pandas as pd 

X_testnormal = pd.read_csv("X_testnormal.csv")
X_trainnormal = pd.read_csv("X_trainnormal.csv")
y_trainnormal = pd.read_csv("y_trainnormal.csv")
test_ids = pd.read_csv("test_ids.csv")

# %%
import optuna 

from xgboost import XGBRegressor
from sklearn.model_selection import train_test_split


from sklearn.metrics import make_scorer, mean_squared_error
import numpy as np

def log_rmse(y_true, y_pred):
    return np.sqrt(mean_squared_error(y_true, y_pred))

log_rmse_scorer = make_scorer(
    log_rmse,
    greater_is_better=False
)

# %%
from sklearn.model_selection import cross_val_score, KFold

from sklearn.model_selection import StratifiedKFold
cv = KFold(
    n_splits=5,
    shuffle=True,
    random_state=42
)
def objective(trial):
    n_estimators = trial.suggest_int("n_estimators",600,1200)
    max_depth = trial.suggest_int("max_depth",4,8)
    learning_rate = trial.suggest_float("learning_rate",0.005,0.3,log=True)
    min_child_weight = trial.suggest_float("min_child_weight",0.5,20,log=True)

    subsample = trial.suggest_float("subsample",0.5,1.0)

    colsample_bytree = trial.suggest_float("colsample_bytree",0.5,1.0)

    gamma = trial.suggest_float("gamma",0,10)

    reg_alpha = trial.suggest_float("reg_alpha",0.02,10,log=True)
    reg_lambda = trial.suggest_float("reg_lambda",0.02,100,log=True)

    model = XGBRegressor(
        n_estimators= n_estimators,
        max_depth = max_depth,
        learning_rate = learning_rate,
        min_child_weight = min_child_weight,
        subsample = subsample,
        colsample_bytree = colsample_bytree,
        gamma = gamma,
        gamma = gamma,
        reg_alpha = reg_alpha,
        reg_lambda = reg_lambda
    )
    
    score = cross_val_score(model, X_trainnormal, y_trainnormal, cv = cv, 
                            scoring = "neg_root_mean_squared_error")
    
    return -score.mean()

study = optuna.create_study(direction="minimize")
study.optimize(objective, n_trials = 100)

print("Best CV score:", study.best_value)
print("Best parameters:", study.best_params)
# Out:
# [I 2026-08-30 00:45:10,464] A new study created in memory with name: no-name-d68cd703-5b63-4639-b4fa-5f1953fff322
# [I 2026-08-30 00:45:18,419] Trial 0 finished with value: 29311.16640625 and parameters: {'n_estimators': 995, 'max_depth': 6, 'learning_rate': 0.05532656803450056, 'min_child_weight': 1.4278792736584152, 'subsample': 0.7241805448308453, 'colsample_bytree': 0.7540193673284259, 'gamma': 0.5158344421447913, 'reg_alpha': 0.10036278932920675, 'reg_lambda': 20.540474946916067}. Best is trial 0 with value: 29311.16640625.
# [I 2026-08-30 00:45:24,437] Trial 1 finished with value: 28570.3390625 and parameters: {'n_estimators': 729, 'max_depth': 6, 'learning_rate': 0.0793926429839746, 'min_child_weight': 0.9466466258288817, 'subsample': 0.6342364321136761, 'colsample_bytree': 0.8574500823149991, 'gamma': 8.817118560495715, 'reg_alpha': 0.3953715530297187, 'reg_lambda': 79.4561023543824}. Best is trial 1 with value: 28570.3390625.
# ...

# %%
XGB_model = XGBRegressor(
    **study.best_params,
    random_state = 42
)

XGB_model.fit(X_trainnormal,y_trainnormal)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.5625966637650467, device=None,
#              early_stopping_rounds=None, enable_categorical=True,
#              eval_metric=None, feature_types=None, feature_weights=None,
#              gamma=0.9397655404095622, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.008114569596471532,
#              max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=8, max_leaves=None,
#              min_child_weight=13.742234311998597, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=979,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
import numpy as np
from sklearn.metrics import root_mean_squared_error, make_scorer
from sklearn.model_selection import cross_val_score

def log_rmse(y_true, y_pred):
    y_pred = np.maximum(y_pred, 0)

    return root_mean_squared_error(
        np.log1p(y_true),
        np.log1p(y_pred)
    )

log_rmse_scorer = make_scorer(
    log_rmse,
    greater_is_better=False
)

scores = cross_val_score(
    XGB_model,
    X_trainnormal,
    y_trainnormal,
    cv=cv,
    scoring=log_rmse_scorer
)

print(-scores)
print("Mean log RMSE:", -scores.mean())
# Out:
# [0.13407633 0.11276392 0.15693949 0.12432978 0.10434209]
# Mean log RMSE: 0.12649032175540925

# %%
preds = XGB_model.predict(X_testnormal)
preds = preds.squeeze()
XGB_model.save_model("xgb_modelnolog.json")

# %%
test_ids = test_ids.squeeze()
df = pd.DataFrame({"Id":test_ids.values, "SalePrice" : preds })

df.to_csv("submissionxgregressornolog.csv", index = False)
