# %%
from sklearn.datasets import fetch_openml
from sklearn.preprocessing import OrdinalEncoder

# %%
data = fetch_openml("car",as_frame = True)
# Out:
# c:\Users\ayush\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\datasets\_openml.py:328: UserWarning: Multiple active versions of the dataset matching the name car exist. Versions may be fundamentally different, returning version 2. Available versions:
# - version 2, status: active
#   url: https://www.openml.org/search?type=data&id=991
# - version 3, status: active
#   url: https://www.openml.org/search?type=data&id=40975
#
#   warn(warning_msg)

# %%
data2 = fetch_openml(as_frame=True)
