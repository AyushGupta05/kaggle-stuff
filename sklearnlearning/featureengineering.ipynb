# %%
customer[["Type", "Level"]] = (customer["Policy"].str.split(" ", expand=True))

# creates type and level features, from policy by splitting on "" and expanding result into seperate columns

# %%
autos["make_and_style"] = autos["make"] + "_" + autos["body_style"]

# this combines features
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 autos["make_and_style"] = autos["make"] + "_" + autos["body_style"]
#       2
#       3 # this combines features
#
# NameError: name 'autos' is not defined

# %%
# group transfomrs aggregates info across multiple rows, grouped by some categroy.
# acerage income of a persons state of residence 

customer ["AverageIncome"] = (customer.groupby("State")["Income"].transform(mean))

# for eaceh state, select the income, and compute its mean

# %%
# K MEANS CLUSTEIRNG YIPEE
